# %%
spark.sql("""select count(1) from `dev_catalog`.`gold`.`gold_traffic`""").display()

# spark.sql("""select * from `dev_catalog`.`gold`.`gold_roads`""").display()

# %%
spark.sql("""select * from `dev_catalog`.`silver`.`silver_traffic` where Link_length_km =0""").display()
