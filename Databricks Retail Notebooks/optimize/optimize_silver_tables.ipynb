# %%
dbutils.widgets.text("env","dev")
env = dbutils.widgets.get("env")

# %%
# %run "/Workspace/Users/azuredataengineer44@gmail.com/databricks-traffic/Databricks Retail Notebooks/common/config_loader"

# %%
config = load_config(env)
catalog = config["unity_catalog"]["catalog"]

# %%
tables = [("products_scd2","product_id"),
          ("customers_scd2","customer_id"),
          ("orders_fact","order_date,customer_id")
]

for table, zorder_cols in tables:
    full_table = f"{catalog}.silver.{table}"
    
    # print(full_table,zorder_cols)

    spark.sql(f"""
              OPTIMIZE {full_table}
              ZORDER BY ({zorder_cols})
              """)

# %%
spark.sql("""DESCRIBE DETAIL dev_catalog.silver.products_scd2""").display();

# %%
spark.sql("""DESCRIBE HISTORY dev_catalog.silver.products_scd2""").display()
