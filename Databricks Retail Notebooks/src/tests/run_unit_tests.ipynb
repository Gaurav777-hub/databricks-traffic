# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
# import sys
# import os

# path = os.getcwd()
# while path != "/" and "src" not in os.listdir(path):
#     path = os.path.dirname(path)

# if path not in sys.path:
#     sys.path.insert(0, path)

# print("Repo root:", path)

# %%
from src.tests.test_products_scd2 import (
    test_scd2_multiple_versions,
    test_deduplication,
    test_late_arriving_event
)

from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

test_scd2_multiple_versions(spark)
test_deduplication(spark)
test_late_arriving_event(spark)

print("✅ All unit tests passed")
